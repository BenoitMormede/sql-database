# %%
import pandas as pd

file_path = '/Users/nancybaraka/Downloads/undesa_pd_2022_hh-size-composition (1).xlsx'
excel_data = pd.ExcelFile(file_path)

excel_data.sheet_names
# Out:
# ['HH size and composition 2022']

# %%
df = excel_data.parse('HH size and composition 2022')

df.head()
# Out:
#   Country or area  ISO Code Data source category Reference date (dd/mm/yyyy)  \
# 0     Afghanistan         4                 MICS         2010-01-07 00:00:00
# 1     Afghanistan         4                  DHS                  19/10/2015
# 2         Albania         8                 MICS         2000-01-07 00:00:00
# 3         Albania         8                 MICS         2005-01-07 00:00:00
# 4         Albania         8                  DHS                  21/01/2009
#
#   Average household size (number of members) 1 member 2-3 members 4-5 members  \
# 0                                       7.75     0.15        7.41       18.59
# 1                                       8.04     0.19        6.45       16.84
# 2                                       4.35     4.42       25.59       47.28
# 3                                          4     5.04       32.37       45.37
# 4                                       3.82     6.15       38.23       39.97
#
# ...

# %%
df.columns
# Out:
# Index(['Country or area', 'ISO Code', 'Data source category',
#        'Reference date (dd/mm/yyyy)',
#        'Average household size (number of members)', '1 member', '2-3 members',
#        '4-5 members', '6 or more members',
#        'Female head of household (percentage of households)',
#        'Under 20 years (aged 0-19)', 'Aged 20-64 years',
#        'Aged 60 years or over', 'Aged 65 years or over',
#        'Under 15 years (aged 0-14)', 'Under 18 years (aged 0-17)',
#        'Under 20 years (aged 0-19).1', 'Aged 60 years or over.1',
#        'Aged 65 years or over.1', 'Under 15 years AND 60 years or over',
#        'Under 15 years AND 65 years or over',
#        'Under 18 years AND 60 years or over',
#        'Under 18 years AND 65 years or over',
#        'Under 20 years AND 60 years or over',
#        'Under 20 years AND 65 years or over',
#        'Under age 15 years among all households',
# ...

# %%
df=df.iloc[4:, :].copy()
df
# Out:
#      Country or area  ISO Code Data source category  \
# 8            Algeria        12                 MICS
# 9             Angola        24                 MICS
# 10            Angola        24                  DHS
# 11            Angola        24                  DHS
# 12            Angola        24                  DHS
# ...              ...       ...                  ...
# 1054        Zimbabwe       716                  DHS
# 1055        Zimbabwe       716                IPUMS
# 1056        Zimbabwe       716                 MICS
# 1057        Zimbabwe       716                  DHS
# 1058        Zimbabwe       716                 MICS
#
#      Reference date (dd/mm/yyyy) Average household size (number of members)  \
# 8            2018-01-07 00:00:00                                       4.94
# 9            2001-01-07 00:00:00                                       4.75
# 10           2007-01-29 00:00:00                                       5.69
# ...

# %%
df = df[['Country or area', 'Reference date (dd/mm/yyyy)', 'Average household size (number of members)']]
df
# Out:
#      Country or area Reference date (dd/mm/yyyy)  \
# 8            Algeria         2018-01-07 00:00:00
# 9             Angola         2001-01-07 00:00:00
# 10            Angola         2007-01-29 00:00:00
# 11            Angola         2011-01-03 00:00:00
# 12            Angola         2016-01-01 00:00:00
# ...              ...                         ...
# 1054        Zimbabwe                  21/12/2010
# 1055        Zimbabwe         2012-01-07 00:00:00
# 1056        Zimbabwe         2014-01-07 00:00:00
# 1057        Zimbabwe                  27/09/2015
# 1058        Zimbabwe         2019-01-07 00:00:00
#
#      Average household size (number of members)
# 8                                          4.94
# 9                                          4.75
# 10                                         5.69
# 11                                         4.98
# 12                                         4.82
# ...                                         ...
# ...

# %%
df['Reference date (dd/mm/yyyy)'] = pd.to_datetime(df['Reference date (dd/mm/yyyy)'], errors='coerce')
df
# Out:
# /var/folders/5j/rbw66y292j36gxy345r1m_sw0000gn/T/ipykernel_30901/4109248755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reference date (dd/mm/yyyy)'] = pd.to_datetime(df['Reference date (dd/mm/yyyy)'], errors='coerce')
#      Country or area Reference date (dd/mm/yyyy)  \
# 8            Algeria                  2018-01-07
# 9             Angola                  2001-01-07
# 10            Angola                  2007-01-29
# 11            Angola                  2011-01-03
# 12            Angola                  2016-01-01
# ...              ...                         ...
# 1054        Zimbabwe                  2010-12-21
# 1055        Zimbabwe                  2012-01-07
# 1056        Zimbabwe                  2014-01-07
# ...

# %%
df['Reference date (dd/mm/yyyy)'] = df['Reference date (dd/mm/yyyy)'].dt.year
df
# Out:
# /var/folders/5j/rbw66y292j36gxy345r1m_sw0000gn/T/ipykernel_30901/20928552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reference date (dd/mm/yyyy)'] = df['Reference date (dd/mm/yyyy)'].dt.year
#      Country or area  Reference date (dd/mm/yyyy)  \
# 8            Algeria                         2018
# 9             Angola                         2001
# 10            Angola                         2007
# 11            Angola                         2011
# 12            Angola                         2016
# ...              ...                          ...
# 1054        Zimbabwe                         2010
# 1055        Zimbabwe                         2012
# 1056        Zimbabwe                         2014
# ...

# %%
df = df.sort_values('Reference date (dd/mm/yyyy)', ascending=False).groupby('Country or area').head(1)

df
# Out:
#                          Country or area  Reference date (dd/mm/yyyy)  \
# 535                               Latvia                         2021
# 376                               Guinea                         2021
# 1035                            Viet Nam                         2020
# 771                    Republic of Korea                         2020
# 803                               Rwanda                         2020
# ...                                  ...                          ...
# 1023  Venezuela (Bolivarian Republic of)                         2001
# 583                             Malaysia                         2000
# 287                    Equatorial Guinea                         2000
# 910                          Switzerland                         2000
# 711                     Papua New Guinea                         2000
#
#      Average household size (number of members)
# 535                                        2.26
# ...

# %%
happiness_df = pd.read_csv('/Users/nancybaraka/Downloads/world_happiness_report_2022.csv')

happiness_df.head()
# Out:
#        country  happiness_score  dystopia_value  explained_by_gdp_per_capita  \
# 0      Finland            7.821           2.518                        1.892
# 1      Denmark            7.636           2.226                        1.953
# 2      Iceland            7.557           2.320                        1.936
# 3  Switzerland            7.512           2.153                        2.026
# 4  Netherlands            7.415           2.137                        1.945
#
#    explained_by_social_support  explained_by_healthy_life_expectancy  \
# 0                        1.258                                 0.775
# 1                        1.243                                 0.777
# 2                        1.320                                 0.803
# 3                        1.226                                 0.822
# 4                        1.206                                 0.787
#
#    explained_by_freedom_to_make_life_choices  explained_by_generosity  \
# ...

# %%
df["Country or area"].unique()
# Out:
# array(['Latvia', 'Guinea', 'Viet Nam', 'Republic of Korea', 'Rwanda',
#        'Gambia', 'Kenya', 'Singapore', 'India', 'Zimbabwe', 'Belarus',
#        'Liberia', 'Kosovo (under UNSC res. 1244)', 'Honduras', 'Nepal',
#        'Guyana', 'Ghana', 'Ethiopia', 'Dominican Republic', 'Cuba',
#        'Bangladesh', 'Chad', 'Malawi', 'Argentina', 'Uganda', 'Thailand',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'State of Palestine', 'Sierra Leone', 'Serbia',
#        'Sao Tome and Principe', 'Samoa', 'Tonga', 'Costa Rica', 'Georgia',
#        'Channel Islands', 'Zambia', 'Central African Republic',
#        'Cameroon', 'Tunisia', 'Benin', 'Mozambique', 'Guinea-Bissau',
#        'Montenegro', 'TFYR Macedonia', 'Suriname', 'Iraq', 'Kiribati',
#        'Kyrgyzstan', 'Lesotho', 'Nigeria', 'New Zealand', 'Mali',
#        'Mongolia', 'Madagascar', 'Algeria', 'Jordan', 'Peru', 'Togo',
#        'Maldives', 'Tajikistan', 'Dem. Republic of the Congo',
# ...

# %%
happiness_df["country"].unique()
# Out:
# array(['Finland', 'Denmark', 'Iceland', 'Switzerland', 'Netherlands',
#        'Luxembourg', 'Sweden', 'Norway', 'Israel', 'New Zealand',
#        'Austria', 'Australia', 'Ireland', 'Germany', 'Canada',
#        'United States', 'United Kingdom', 'Czechia', 'Belgium', 'France',
#        'Bahrain', 'Slovenia', 'Costa Rica', 'United Arab Emirates',
#        'Saudi Arabia', 'Taiwan Province of China', 'Singapore', 'Romania',
#        'Spain', 'Uruguay', 'Italy', 'Kosovo', 'Malta', 'Lithuania',
#        'Slovakia', 'Estonia', 'Panama', 'Brazil', 'Guatemala',
#        'Kazakhstan', 'Cyprus', 'Latvia', 'Serbia', 'Chile', 'Nicaragua',
#        'Mexico', 'Croatia', 'Poland', 'El Salvador', 'Kuwait', 'Hungary',
#        'Mauritius', 'Uzbekistan', 'Japan', 'Honduras', 'Portugal',
#        'Argentina', 'Greece', 'South Korea', 'Philippines', 'Thailand',
#        'Moldova', 'Jamaica', 'Kyrgyzstan', 'Belarus', 'Colombia',
#        'Bosnia and Herzegovina', 'Mongolia', 'Dominican Republic',
# ...

# %%
df['Country or area'] = df['Country or area'].str.strip().str.lower()
happiness_df['country'] = happiness_df['country'].str.strip().str.lower()

# %%
country_mapping = {
    'viet nam': 'vietnam',
    'republic of korea': 'south korea',
    'state of palestine': 'palestinian territories',
    'kosovo (under unsc res. 1244)': 'kosovo',
}

df['Country or area'] = df['Country or area'].replace(country_mapping)

df
# Out:
#                          Country or area  Reference date (dd/mm/yyyy)  \
# 535                               latvia                         2021
# 376                               guinea                         2021
# 1035                             vietnam                         2020
# 771                          south korea                         2020
# 803                               rwanda                         2020
# ...                                  ...                          ...
# 1023  venezuela (bolivarian republic of)                         2001
# 583                             malaysia                         2000
# 287                    equatorial guinea                         2000
# 910                          switzerland                         2000
# 711                     papua new guinea                         2000
#
#      Average household size (number of members)
# 535                                        2.26
# ...

# %%
output_file_path = '/Users/nancybaraka/Downloads/updated_household_size_data.xlsx'
df.to_excel(output_file_path, index=False)

output_file_path
# Out:
# '/Users/nancybaraka/Downloads/updated_household_size_data.xlsx'
