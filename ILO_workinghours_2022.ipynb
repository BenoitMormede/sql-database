# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/nancybaraka/Downloads/HOW_TEMP_SEX_AGE_ECO_NB_A-20241001T1541.csv', delimiter=',')
# Out:
# /var/folders/5j/rbw66y292j36gxy345r1m_sw0000gn/T/ipykernel_17703/3252933965.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/nancybaraka/Downloads/HOW_TEMP_SEX_AGE_ECO_NB_A-20241001T1541.csv', delimiter=',')

# %%
df_2 = pd.read_csv('/Users/nancybaraka/Downloads/API_NY.GDP.PCAP.KN_DS2_en_csv_v2_31781/API_NY.GDP.PCAP.KN_DS2_en_csv_v2_31781.csv', delimiter=';')

# %%
df_2
# Out:
#                     Country Name Country Code
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                        Yemen         Rep.
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
# [266 rows x 2 columns]

# %%
df.head()
# Out:
#   ref_area.label               source.label  \
# 0    Afghanistan  LFS - Labour Force Survey
# 1    Afghanistan  LFS - Labour Force Survey
# 2    Afghanistan  LFS - Labour Force Survey
# 3    Afghanistan  LFS - Labour Force Survey
# 4    Afghanistan  LFS - Labour Force Survey
#
#                                      indicator.label   sex.label  \
# 0  Mean weekly hours actually worked per employed...  Sex: Total
# 1  Mean weekly hours actually worked per employed...  Sex: Total
# 2  Mean weekly hours actually worked per employed...  Sex: Total
# 3  Mean weekly hours actually worked per employed...  Sex: Total
# 4  Mean weekly hours actually worked per employed...  Sex: Total
#
#              classif1.label                                    classif2.label  \
# 0  Age (Youth, adults): 15+           Economic activity (Broad sector): Total
# 1  Age (Youth, adults): 15+     Economic activity (Broad sector): Agriculture
# ...

# %%
column_names = df.columns.tolist()
column_names
# Out:
# ['ref_area.label',
#  'source.label',
#  'indicator.label',
#  'sex.label',
#  'classif1.label',
#  'classif2.label',
#  'time',
#  'obs_value',
#  'obs_status.label',
#  'note_classif.label',
#  'note_indicator.label',
#  'note_source.label']

# %%
# Renaming 'ref_area.label' to 'Country'
df.rename(columns={'ref_area.label': 'Country'}, inplace=True)

# Displaying the updated column names to confirm the change
df.columns.tolist()
# Out:
# ['Country',
#  'source.label',
#  'indicator.label',
#  'sex.label',
#  'classif1.label',
#  'classif2.label',
#  'time',
#  'obs_value',
#  'obs_status.label',
#  'note_classif.label',
#  'note_indicator.label',
#  'note_source.label']

# %%
# Assuming the dataframe is loaded, now let's get the unique values for the column 'indicator.label'

unique_indicators = df['indicator.label'].unique()
unique_indicators
# Out:
# array(['Mean weekly hours actually worked per employed person by sex, age and economic activity'],
#       dtype=object)

# %%
unique_indicators = df['sex.label'].unique() #'Sex: Total'
unique_indicators
# Out:
# array(['Sex: Total', 'Sex: Male', 'Sex: Female', 'Sex: Other'],
#       dtype=object)

# %%
df = df[df['classif1.label'] == 'Age (Aggregate bands): Total']

df = df[df['sex.label'] == 'Sex: Total']

# %%
unique_indicators = df['classif2.label'].unique() #'Economic activity (Broad sector): Total'
unique_indicators

df = df[df['classif2.label'] == 'Economic activity (Broad sector): Total']

# %%
unique_indicators = df['time'].unique() #'2021'
unique_indicators

df = df[df['time'] == 2021]

# %%
df.columns
# Out:
# Index(['Country', 'source.label', 'indicator.label', 'sex.label',
#        'classif1.label', 'classif2.label', 'time', 'obs_value',
#        'obs_status.label', 'note_classif.label', 'note_indicator.label',
#        'note_source.label'],
#       dtype='object')

# %%
df
# Out:
#                           Country                             source.label  \
# 262                   Afghanistan                LFS - Labour Force Survey
# 3685                       Angola                  LFS - Employment Survey
# 5715                      Albania                LFS - Labour Force Survey
# 25982                   Argentina  LFS - Permanent Household Survey, Urban
# 66535                     Austria                LFS - Labour Force Survey
# ...                           ...                                      ...
# 1685891  United States of America          LFS - Current Population Survey
# 1717643                  Viet Nam                LFS - Labour Force Survey
# 1742378              South Africa      LFS - Quarterly Labour Force Survey
# 1764891                    Zambia                LFS - Labour Force Survey
# 1771939                  Zimbabwe                LFS - Labour Force Survey
#
# ...

# %%
# Selecting only 'Country' and 'obs_value' columns
df = df[['Country', 'obs_value']]

# Display the first few rows to confirm the changes
df
# Out:
#                           Country  obs_value
# 262                   Afghanistan      39.62
# 3685                       Angola      41.35
# 5715                      Albania      41.35
# 25982                   Argentina      36.39
# 66535                     Austria      33.33
# ...                           ...        ...
# 1685891  United States of America      38.06
# 1717643                  Viet Nam      41.38
# 1742378              South Africa      42.35
# 1764891                    Zambia      42.58
# 1771939                  Zimbabwe      41.33
#
# [93 rows x 2 columns]

# %%
df.reset_index(drop=True, inplace=True)

df
# Out:
#                      Country  obs_value
# 0                Afghanistan      39.62
# 1                     Angola      41.35
# 2                    Albania      41.35
# 3                  Argentina      36.39
# 4                    Austria      33.33
# ..                       ...        ...
# 88  United States of America      38.06
# 89                  Viet Nam      41.38
# 90              South Africa      42.35
# 91                    Zambia      42.58
# 92                  Zimbabwe      41.33
#
# [93 rows x 2 columns]

# %%
df.rename(columns={'obs_value': 'weekly_working_hours'}, inplace=True)

df.rename(columns={'Country': 'country'}, inplace=True)

df
# Out:
#                      country  weekly_working_hours
# 0                Afghanistan                 39.62
# 1                     Angola                 41.35
# 2                    Albania                 41.35
# 3                  Argentina                 36.39
# 4                    Austria                 33.33
# ..                       ...                   ...
# 88  United States of America                 38.06
# 89                  Viet Nam                 41.38
# 90              South Africa                 42.35
# 91                    Zambia                 42.58
# 92                  Zimbabwe                 41.33
#
# [93 rows x 2 columns]

# %%
# Check if all countries in the original dataset exist in the World Bank dataset
matching_countries = df['country'].isin(df_2['Country Name']).all()

# Display whether all countries match
matching_countries
# Out:
# False

# %%
# Find countries in the original dataset that don't match any in the World Bank dataset
mismatched_countries = df[~df['country'].isin(df_2['Country Name'])]['country'].unique()

# Display the mismatched countries
mismatched_countries
# Out:
# array(['Bolivia (Plurinational State of)',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'Iran (Islamic Republic of)', 'Kyrgyzstan', 'Republic of Korea',
#        'Saint Lucia', 'Republic of Moldova',
#        'Occupied Palestinian Territory', 'Slovakia', 'Türkiye',
#        'United States of America'], dtype=object)

# %%
# Dictionary to map the mismatched country names
country_name_mapping = {
    'Bolivia (Plurinational State of)': 'Bolivia',
    'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
    'Iran (Islamic Republic of)': 'Iran',
    'Republic of Korea': 'Korea, Rep.',
    'Saint Lucia': 'St. Lucia',
    'Republic of Moldova': 'Moldova',
    'Occupied Palestinian Territory': 'West Bank and Gaza',
    'Türkiye': 'Turkey',
    'United States of America': 'United States'
}

# Replace the country names in the original dataset using the mapping
df['country'].replace(country_name_mapping, inplace=True)

# Check if all countries now match
matching_countries_after_correction = df['country'].isin(df_2['Country Name']).all()

matching_countries_after_correction
# Out:
# /var/folders/5j/rbw66y292j36gxy345r1m_sw0000gn/T/ipykernel_17703/2455302029.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].replace(country_name_mapping, inplace=True)
# False

# %%
unique_indicators = df['country'].unique() 
unique_indicators
# Out:
# array(['Afghanistan', 'Angola', 'Albania', 'Argentina', 'Austria',
#        'Belgium', 'Bulgaria', 'Bosnia and Herzegovina', 'Belarus',
#        'Bolivia', 'Brazil', 'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Canada', 'Switzerland', 'Chile', 'Colombia', 'Comoros',
#        'Costa Rica', 'Cyprus', 'Czechia', 'Germany', 'Denmark',
#        'Dominican Republic', 'Egypt', 'Spain', 'Estonia', 'Ethiopia',
#        'Finland', 'France', 'United Kingdom', 'Greece', 'Honduras',
#        'Croatia', 'Hungary', 'Indonesia', 'India', 'Ireland', 'Iran',
#        'Iraq', 'Iceland', 'Israel', 'Italy', 'Jamaica', 'Jordan',
#        'Kyrgyzstan', 'Cambodia', 'Korea, Rep.', 'Kosovo', 'St. Lucia',
#        'Sri Lanka', 'Lithuania', 'Luxembourg', 'Latvia', 'Moldova',
#        'Mexico', 'Marshall Islands', 'North Macedonia', 'Malta',
#        'Montenegro', 'Mongolia', 'Mauritius', 'Netherlands', 'Norway',
#        'Nauru', 'Pakistan', 'Panama', 'Peru', 'Philippines', 'Poland',
# ...

# %%
unique_indicators = df_2['Country Name'].unique() 
unique_indicators
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo', 'Colombia',
#        'Comoros', 'Cabo Verde', 'Costa Rica', 'Caribbean small states',
#        'Cuba', 'Curacao', 'Cayman Islands', 'Cyprus', 'Czechia',
#        'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic',
# ...

# %%
# Updating the country name mapping to handle additional mismatches
country_name_mapping.update({
    'Korea, Rep.': 'Korea',
    'Turkey': 'Turkiye'
})

# Replace the country names in the original dataset using the updated mapping
df['country'].replace(country_name_mapping, inplace=True)

# Check if all countries now match after the new corrections
matching_countries_after_correction = df['country'].isin(df_2['Country Name']).all()

matching_countries_after_correction
# Out:
# False

# %%
# Find the remaining unmatched countries
remaining_mismatched_countries = df[~df['country'].isin(df_2['Country Name'])]['country'].unique()

# Display the remaining unmatched countries
remaining_mismatched_countries
# Out:
# array(['Kyrgyzstan', 'Slovakia'], dtype=object)

# %%
# Updating the country name mapping to handle 'Kyrgyzstan' and 'Slovakia'
country_name_mapping.update({
    'Kyrgyzstan': 'Kyrgyz Republic',
    'Slovakia': 'Slovak Republic'
})

# Replace the country names in the original dataset using the updated mapping
df['country'].replace(country_name_mapping, inplace=True)

# Check if all countries now match after the new corrections
matching_countries_after_correction = df['country'].isin(df_2['Country Name']).all()

matching_countries_after_correction
# Out:
# True

# %%
df
# Out:
#           country  weekly_working_hours
# 0     Afghanistan                 39.62
# 1          Angola                 41.35
# 2         Albania                 41.35
# 3       Argentina                 36.39
# 4         Austria                 33.33
# ..            ...                   ...
# 88  United States                 38.06
# 89       Viet Nam                 41.38
# 90   South Africa                 42.35
# 91         Zambia                 42.58
# 92       Zimbabwe                 41.33
#
# [93 rows x 2 columns]

# %%
# Save the updated dataframe to a CSV file
output_file_path = '/mnt/data/updated_dataset.csv'
df_selected.to_csv(output_file_path, index=False)

# Provide the download link for the user
output_file_path
